# %% [markdown]
# ## 作業1： Wine Review
# https://www.kaggle.com/zynicide/wine-reviews#winemag-data-130k-v2.csv
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要：
# >因為這樣以後就可以用紅酒的感覺來找到到底是哪一支紅酒了！
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# >於2017年6月15號從WineEnthusiast由作者爬下來的
#
# 3. 蒐集而來的資料型態為何
# >包含兩個excel sheet及一個json檔，包含紅酒的相關各種資料
#
# 4. 這組資料想解決的問題如何評估
# >利用資料當中大量的侍酒師評價來進行deep learning，之後利用其他侍酒師給的敘述來預測到底是哪一支紅酒。
# 用F1 auuracy來判斷是否有正確判斷

# %% [markdown]
# ## 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# > 如果司機不要廢話很多的話應該可以提升業績
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# > 詢問司機是否會於載客時間與客人聊天。因為各司機跑的路線本身就會影響自身的業績，所以回來資料要再進行相同區域的司機比較，不能跨區域類型比較（市中心對市中心、郊區對郊區）
#
# 3. 蒐集而來的資料型態為何
# > 除司機載客是否與客人聊天需要另外輸入（口頭或問卷詢問），其餘皆可從業績報表中看出。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# > 在同類型的區域（市中心對市中心、郊區對郊區）進行組內比較，來驗證假設。

# %%
import numpy as np
import matplotlib.pylab as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_square_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

MSE = mean_square_error(y, y_hat)
print("The Mean square error is %.3f" % (MSE))
# Out:
# The Mean square error is 153.820
